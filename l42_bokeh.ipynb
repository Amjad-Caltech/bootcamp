# %% [markdown]
# # Lesson 42: Interactive plotting with Bokeh
#
# (c) 2017 Justin Bois. This work is licensed under a [Creative Commons Attribution License CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/). All code contained herein is licensed under an [MIT license](https://opensource.org/licenses/MIT).
#
# *This tutorial was generated from an Jupyter notebook.  You can download the notebook [here](l42_bokeh.ipynb).*

# %%
import numpy as np
import pandas as pd

import skimage
import skimage.io

# Use IPython widgets for interacting
import ipywidgets

# Import Bokeh modules for interactive plotting
import bkcharts
import bokeh.io
import bokeh.models
import bokeh.palettes
import bokeh.plotting

# Package to convert SVG to PDF
#import cairosvg

# I like the default Matplotlib palette
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']

# Display graphics in this notebook
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f37eb31b-f89c-4648-a936-55406e8d732d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Before we begin, it is important that you are using the latest version of Bokeh, v. 0.12.6. After importing, verify that this is the case.

# %%
bokeh.__version__
# Out:
# '0.12.6'

# %% [markdown]
# If you need to update Bokeh, you may do so at the command line:
#
#     conda update bokeh

# %% [markdown]
# Importantly, Bokeh is gearing up for its 1.0 release, which means there may be some API changes in the not-so-distant future. And there will certainly be enhancements. Bear this in mind in this lesson and when writing code that uses Bokeh.
#
# It is useful to interact with our data.  [Bokeh](http://bokeh.pydata.org/en/latest/) (pronounced "BOH-kay") facilitates this. While I like Matplotlib and  we've used it to great effect in the bootcamp, I actually prefer Bokeh's native syntax for generating graphics better.  It is based on [grammar of graphics](http://www.amazon.com/The-Grammar-Graphics-Statistics-Computing/dp/0387245448), which is more conceptually clean way to think about graphical display of data. In fact, because Bokeh became endowed with the ability to export vector graphics just five days before the bootcamp, I contemplated doing the entire bootcamp using Bokeh for many reasons, including its better grammar.

# %% [markdown]
# ### The data set
# In this lesson, we will explore some of Bokeh's features using the finch beak data from [Exercise 4](l33_exercise_4.html). Upon completing that exercise, you should have created a tidy data frame with the data for several years and stored it in `data/grant_complete.csv` in you repo. If you did not, that's ok; I put it in there. You can do
#
#     git pull origin upstream
#
# and you will have it. So, let's load the data set.

# %%
df = pd.read_csv('data/grant_complete.csv')

# %% [markdown]
# To remind us what is in the data set, let's take a quick look.

# %%
df.head()
# Out:
#     band  beak depth (mm)  beak length (mm) species  year
# 0  20123             8.05              9.25  fortis  1973
# 1  20126            10.45             11.35  fortis  1973
# 2  20128             9.55             10.15  fortis  1973
# 3  20129             8.75              9.95  fortis  1973
# 4  20133            10.15             11.55  fortis  1973

# %% [markdown]
# We have beak depth and beak length data for two different species, *G. fortis* and *G. scandens* for a variety of years.

# %% [markdown]
# ## Using bkcharts for high level plots
#
# Much like Seaborn enables high-level plotting where you input a `DataFrame`, which columns you want, while specifying the type of plot, Bokeh offers similar functionality through the `bkcharts` module. Let's take it for a spin.
#
# We'll start by making a scatter plot of beak depth versus beak lengths for both *G. fortis* and *G. scandens* in 1987.

# %%
p = bkcharts.Scatter(df.loc[df['year']==1987, :], x='beak length (mm)', y='beak depth (mm)',
                     color='species')
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0ad84919-6709-44f4-b3cf-3849fc555b38"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0ad84919-6709-44f4-b3cf-3849fc555b38");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0ad84919-6709-44f4-b3cf-3849fc555b38");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0ad84919-6709-44f4-b3cf-3849fc555b38' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aa3074f2-e658-4161-9e0c-eea5fb4b2157":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"}],"species":["scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scand ...

# %% [markdown]
# First, let's comment on the syntax. The scatter plot is invoked using the `bkchart.Scatter()` function, and it returns a `bkcharts.chart.Chart` object. To show the plot, we need to call `bokeh.io.show(p)`. It is then rendered in the Jupyter notebook. Note that in order to do this, we had to call `bokeh.io.output_notebook()` earlier to specify that the output goes to the notebook. Otherwise, the output will be an HTML file that you can open in a browser.
#
# Now, some of the default settings on the plot are less desirable. For example, the colors are bad. Red and green are never good choice, not just because of poor aesthetics, but also because it is a problem for red-green colorblind people. Furthermore, we might want to adjust the shape of the plot so it is not so long in the vertical direction. We can change these things via kwargs in our function call to generate the scatter plot.

# %%
p = bkcharts.Scatter(df.loc[df['year']==1987, :], x='beak length (mm)', y='beak depth (mm)',
                     color='species', palette=colors, width=600, height=400)
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2ff8ed86-400d-4b9b-938a-cef57b33a7f7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2ff8ed86-400d-4b9b-938a-cef57b33a7f7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2ff8ed86-400d-4b9b-938a-cef57b33a7f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2ff8ed86-400d-4b9b-938a-cef57b33a7f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1801ead2-f782-4e40-8281-744c1cb0aa11":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9154372b-9b57-4943-b4bd-bc0f39ae69ad","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"d31b17c1-0408-47ee-829a-f24ad2db9b54","subtype":"Chart","type":"Plot"}},"id":"ddbc6cb8-833a-4c4a-a326-b28eea703906","type":"SaveTool"},{"attributes":{"plot":{"id":"d31b17c1-0408-47ee-829a-f24ad2db9b54","subtype":"Chart","type":"Plot"}},"id":"9e9e5e72-76de-447b-882d-652f878fe2aa","type":"ResetTool"},{"attributes":{"plot":{"id":"d31b17c1-0408-47ee-829a-f24ad2db9b54","subtype":"Chart","type":"Plot"}},"id":"ad37dc1f-bcd5-4a2f-91bb-7753fa11dca6","type":"HelpTool"},{"attributes":{"label":{"value":"scandens"},"renderers":[{"id":"5e8dc5fb-b0d2-4551-bed4-305470c6b453","type":"GlyphRenderer"}]},"id":"4de8ec67-2606-4fd9-b68f-520fe18b4093","type":"LegendItem"},{"attributes":{"axis_label":"beak depth (mm)","formatter":{"id":"c67a5700-61ba-4bb4-a990-0f0d8c8cf19c","type":"BasicTickFormatter"},"plot":{"id":"d31b17c1-0408-47ee-829a-f24ad2db9b54","subtype":"Chart","type":"Plot"},"ticker":{"id":"a3915ee8-1956-4ce4-b66e-998af205e713","type":"BasicTicker"}},"id":"d19494c8-0fe5-42ec-8c87-8b8502ef6c74","type":"LinearAxis"},{"attributes":{"axis_label":"beak length (mm)","formatter":{"id":"798a8677-1664-428d-b6cb-fcea50a4b489","type":"BasicTickFormatter"},"plot":{"id":"d31b17c1-0408-47ee-829a-f24ad2db9b54","subtype":"Chart","type":"Plot"},"ticker":{"id":"82f8f618-160d-488b-aebd-2a7a1384c80f","type":"BasicTicker"}},"id":"872077ed-ccbe-475f-bc18-85143adb5e4c","type":"LinearAxis"},{"attributes":{},"id":"82f8f618-160d-488b-aebd-2a7a1384c80f","type":"BasicTicker"},{"attributes":{"plot":{"id":"d31b17c1-0408-47ee-829a-f24ad2db9b54","subtype":"Chart","type":"Plot"},"ticker":{"id":"82f8f618-160d-488b-aebd-2a7a1384c80f","type":"BasicTicker"}},"id":"8c54868a-ff13-46ed-b17d-9fb84c73dab6","type":"Grid"},{"attributes":{},"id":"a3915ee8-1956-4ce4-b66e-998af205e713","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species":"scandens"},{"species": ...

# %% [markdown]
# Much nicer! Note that the width and height units are pixels. Note also that you can interact with the plot! (That's the most important part!)

# %% [markdown]
# ### Hover tools
#
# Given that we can interact with the plot, let's take full advantage. Let's say we want to know which bird (band number) corresponds to which data point. When we're interacting with the plot, we would like a bubble to pop up saying the band number of the bird corresponding to the data point over which we are hovering. We can set this up by specifying **tooltips**, which say which information to show when you hover. The tooltips consist of a list of 2-tuples. Each tuple contains a string with the label for the hover bublle and another string containing the column of the DataFrame to use for the label. The latter should be preceded with an "`@`".

# %%
tooltips=[('band', '@band')]

p = bkcharts.Scatter(df.loc[df['year']==1987, :], x='beak length (mm)', y='beak depth (mm)',
                     color='species', tooltips=tooltips, palette=colors, width=600, height=400)
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="07b383ac-3ce8-4692-a9be-17722b2f0a0b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("07b383ac-3ce8-4692-a9be-17722b2f0a0b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("07b383ac-3ce8-4692-a9be-17722b2f0a0b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '07b383ac-3ce8-4692-a9be-17722b2f0a0b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c6009d2c-35c6-4e39-ae3a-b1200480674a":{"roots":{"references":[{"attributes":{"axis_label":"beak depth (mm)","formatter":{"id":"86689288-5702-4219-9a4c-81721240d392","type":"BasicTickFormatter"},"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"},"ticker":{"id":"aaa0cab5-479d-446a-94cb-bd13bfa388d8","type":"BasicTicker"}},"id":"ee4b2aa9-d14b-40ad-90d7-34a2c855c6f4","type":"LinearAxis"},{"attributes":{"data_source":{"id":"f4d957ef-e060-4454-a69a-d3c89e9a3edf","type":"ColumnDataSource"},"glyph":{"id":"770f4dff-9fe9-4944-ada2-3c7b5493c3dc","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"74f011b0-7495-48ee-9be9-69dc218672ef","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#ff7f0e"},"line_color":{"value":"#ff7f0e"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"770f4dff-9fe9-4944-ada2-3c7b5493c3dc","type":"Circle"},{"attributes":{"plot":null,"text":null},"id":"83a32684-48f0-4146-980c-3c9b7f3c8991","type":"Title"},{"attributes":{},"id":"f7b682ac-5167-42d1-a882-eb7be908f47d","type":"LinearScale"},{"attributes":{"label":{"value":"scandens"},"renderers":[{"id":"74f011b0-7495-48ee-9be9-69dc218672ef","type":"GlyphRenderer"}]},"id":"172a057a-3973-4294-ab42-1017d309235b","type":"LegendItem"},{"attributes":{"label":{"value":"fortis"},"renderers":[{"id":"e30417e3-d8c7-4107-ad6b-873c3fecef44","type":"GlyphRenderer"}]},"id":"14b879ab-2839-4155-b518-854c5841ee5e","type":"LegendItem"},{"attributes":{"items":[{"id":"14b879ab-2839-4155-b518-854c5841ee5e","type":"LegendItem"},{"id":"172a057a-3973-4294-ab42-1017d309235b","type":"LegendItem"}],"location":"top_left","plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"}},"id":"a01a5e4c-eb12-42a2-b1a2-9b9d48bf367f","type":"Legend"},{"attributes":{"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"}},"id":"a2bc5978-f155-4cf5-9c0f-545c7fe0f5dc","type":"PanTool"},{"attributes":{},"id":"9d1563f6-7834-48d4-b835-6792db42f797","type":"LinearScale"},{"attributes":{"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"}},"id":"3a99a848-5519-49eb-909b-1faa039a5a71","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"319d0bd6-874b-491d-a8aa-9de89eb8c1b8","type":"BoxAnnotation"},"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"}},"id":"be2f8589-f7ca-44ad-9567-3b085591db1e","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"}},"id":"d3fa40ec-26b0-4580-8d63-40a011c57fe9","type":"SaveTool"},{"attributes":{"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"}},"id":"25631183-b800-475b-8875-5de52f982de2","type":"ResetTool"},{"attributes":{"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"}},"id":"a6d76ae6-923a-43c9-9575-ba6ad9337c0d","type":"HelpTool"},{"attributes":{"axis_label":"beak length (mm)","formatter":{"id":"d5e6636e-5426-4c17-b90f-aec08d23fb80","type":"BasicTickFormatter"},"plot":{"id":"829e1d17-adf5-4bed-a7fa-7c7accd64e82","subtype":"Chart","type":"Plot"},"ticker":{"id":"a3c9647c-580e-4b4b-a1c7-c69343ac317e","type":"BasicTicker"}},"id":"0cdc9e21-ab76-404a-9750-c2c3439ccdf6","type":"LinearAxis"},{"attributes":{},"id":"a3c9647c-580e-4b4b-a1c7-c69343ac317e","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values","band"],"data":{"band":[14613,15487,15187,15284,14983,14913,15726,15821,15484,4968,15695,15272,15256,13907,5578,10376,13377,15225,15914,14760,15779,13901,15277,15285,13194,14967,14800,14612,15154,14123,15368,15873,16027,15353,14265,15014,14969,5627,15973,13468,15214,14978,15909,13996,13543,14634,15804,15493,15363,15286,15019,16112,15270,15874,16007,14860,10313,15490,15106,13539,14912,13244,14822,14909,15944,16170,15477,15111,14686,15915,15759,15850,159 ...

# %% [markdown]
# ### Other high level plots
#
# Bokeh offers other high-level plots (but unfortunately not yet swarm plots). For example, we can make a box plot of beak depths in 1987.

# %%
p = bkcharts.BoxPlot(df.loc[df['year']==1987, :], label='species', values='beak length (mm)',
                     width=400, height=400, legend=False)
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c45bdaf0-58ad-42d7-93b2-dfff2803068b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c45bdaf0-58ad-42d7-93b2-dfff2803068b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c45bdaf0-58ad-42d7-93b2-dfff2803068b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c45bdaf0-58ad-42d7-93b2-dfff2803068b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aa83efbc-76e2-49d3-bdf1-c95ac3d45439":{"roots":{"references":[{"attributes":{"data_source":{"id":"10500bd0-c3e7-4d35-8396-0ebbbafd9aca","type":"ColumnDataSource"},"glyph":{"id":"51d37c24-656c-4dfc-b64b-2ea46f37744c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"adda9f0d-551d-4e03-bc62-18d53a77fa69","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"025fdea2-fb71-4bed-863b-2778c3be1960","type":"Title"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c91e8b1e-92e5-4cc2-8695-e2143a6e7caa","type":"PanTool"},{"id":"627f48d2-9c84-4e72-8cd1-8813a4497de7","type":"WheelZoomTool"},{"id":"5184f513-38ae-4284-8d98-a5039841c40a","type":"BoxZoomTool"},{"id":"240a34ee-501d-4ce5-ac87-1d0c8af354b6","type":"SaveTool"},{"id":"6f94889c-0e43-4e13-8412-9de83df6f532","type":"ResetTool"},{"id":"c7c4d63d-1ebb-45cd-ac3a-382494331090","type":"HelpTool"}]},"id":"40df3687-e609-4ee9-93c9-6004880d7245","type":"Toolbar"},{"attributes":{},"id":"4756af1a-0d03-4238-9066-89f49f93d6ed","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"species":"scandens"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.4175000000000004],"label":[{"species":"scandens"}],"line_alpha":[1.0],"line_color":["black"],"species":["scandens"],"width":[0.8],"x":["scandens"],"y":[14.046249999999999]}},"id":"d5b18fe8-7162-4760-a393-4f17fa505a3f","type":"ColumnDataSource"},{"attributes":{},"id":"b9b34f1f-5437-4e3e-a844-d3717746139d","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b4aaf06c-2157-46b2-bd7e-d914e15ebe01","type":"BoxAnnotation"},{"attributes":{"axis_label":"Beak Length (Mm)","formatter":{"id":"bdb4c484-ac9b-4b7e-8d69-88864181e9f6","type":"BasicTickFormatter"},"plot":{"id":"6d3364dc-f10b-4ed1-afbe-6e3a0537d571","subtype":"Chart","type":"Plot"},"ticker":{"id":"efea8181-80cd-425d-8736-59b5fa8f242c","type":"BasicTicker"}},"id":"fe1a143a-d234-4df1-a9d3-61342cc0c16b","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"species":"scandens"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.5625],"label":[{"species":"scandens"}],"line_alpha":[1.0],"line_color":["black"],"species":["scandens"],"width":[0.8],"x":["scandens"],"y":[14.536249999999999]}},"id":"50a0acc0-cb3c-45e5-93f0-b69e226617ea","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"bf9900c4-33c5-41dc-81bd-aae16b2297b8","type":"ColumnDataSource"},"glyph":{"id":"4c26a5cc-d320-44a2-9871-1bef25f2ff28","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"61b31d70-757c-46dd-ad5a-435d85eead39","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["fortis","scandens"]},"id":"53d67431-a150-4cfd-bf1d-397b7def3151","type":"FactorRange"},{"attributes":{},"id":"efea8181-80cd-425d-8736-59b5fa8f242c","type":"BasicTicker"},{"attributes":{"plot":{"id":"6d3364dc-f10b-4ed1-afbe-6e3a0537d571","subtype":"Chart","type":"Plot"}},"id":"c91e8b1e-92e5-4cc2-8695-e2143a6e7caa","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d1324fbb-bbd4-4146-8a03-6f6ff078e6e1","type":"Rect"},{"attributes":{"axis_label":"Species","formatter":{"id":"c8daef58-3571-4fec-af6f-95dc1d0c7317","type":"CategoricalTickFormatter"},"major_label_orientation":0.78539816339 ...

# %% [markdown]
# We will not dwell more on the high level plotting capabilities, but will focus instead on the lower level plotting capabilities of Bokeh. The lower level plotting functions allow for much more configurability.

# %% [markdown]
# ## Bokeh's lower level plotting
#
# The pipeline for making a plot using Bokeh is to first specify the "canvas" on which you want to paint your data, and then "paint" your data. For example, if we wanted to make a scatter plot of the beak length/depth data, we first think about what space it should occupy. Specifically, we want a figure that is in Cartesian coordinates 400 pixels high and 600 wide. Now, we can start thinking about what we want each axis in the plot to represent. We will say that the x-axis represents beak length and the y-axis beak depth. So, the first thing we do is to make a figure we will work with. So far, the data are not involved at all in the plotting process.

# %%
# Build figure
p = bokeh.plotting.figure(height=400, width=600, x_axis_label='beak length (mm)',
                         y_axis_label='beak depth (mm)')

# %% [markdown]
# Next, we might think about what we want to happen when we hover over the data. We will display the band number, and also the values of the beak length and depth (just to demonstrate how to format numbers in the hover). Notice that specifying hovers with columns that have spaces, we place the column name in braces. The braces following specify the format for display of the number, in this case as a floating with two places past the decimal.

# %%
# Set up hover tool
hover = bokeh.models.HoverTool(tooltips=[('band', '@band'), 
                                         ('length', '@{beak length (mm)}{0.2f}'),
                                         ('depth', '@{beak depth (mm)}{0.2f}')])

# Add the tool to the figure
p.add_tools(hover)

# %% [markdown]
# Note that we still have not invoked the actual data. We have been setting up the space the data will occupy and how we will interact with it. Now that that is all in place, we can start to populate our plot with data. First, let's set up the indices we want for extraction from the (tidy) `DataFrame` of finch beak data.

# %%
# For convenience, the indices we want for the species
inds_f = (df['year']==1987) & (df['species']=='fortis')
inds_s = (df['year']==1987) & (df['species']=='scandens')

# %% [markdown]
# Now, it's a matter of populating the plot with the data. In Bokeh, the figure we created has methods for populating it with data. The name of the method is the name of the **glyph** you want to use to represent your data. In our case, we will use a circle. The `p.circle()` function takes $x$ and $y$ values as inputs. These may be either Numpy arrays, lists, or column headings in a `DataFrame`. If they are the latter, we specify a data source using the `source` kwarg.

# %%
# Paint the glyphs
p.circle('beak length (mm)', 'beak depth (mm)', source=df.loc[inds_f, :], color=colors[0], 
         alpha=0.25, name = 'Fortis')
p.circle('beak length (mm)', 'beak depth (mm)', source=df.loc[inds_s, :], color=colors[1],
         alpha=0.25, name='Scanden')

bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="750bf46e-cd37-4cda-9f16-ceeae89fe147"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("750bf46e-cd37-4cda-9f16-ceeae89fe147");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("750bf46e-cd37-4cda-9f16-ceeae89fe147");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '750bf46e-cd37-4cda-9f16-ceeae89fe147' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0a56c693-0308-4e61-a5a9-857dc6f23c44":{"roots":{"references":[{"attributes":{},"id":"b94786cf-862f-4dcc-993d-734ebd53fbb1","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"beak length (mm)"},"y":{"field":"beak depth (mm)"}},"id":"dc6da0ea-5186-471d-87e4-b363ea650f27","type":"Circle"},{"attributes":{},"id":"5e6e0c2a-08a5-4b25-87ac-e4bb666ef2fb","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["band","beak depth (mm)","beak length (mm)","species","year","index"],"data":{"band":[15718,5594,15235,15252,15847,15139,15237,4045,8443,15798,14786,364,10001,15119,15676,15476,14576,15419,15635,2733,15751,14834,4109,15901,14830,15086,15986,4223,15725,13554,15407,3425,15704,15102,5582,15121,10770,14755,13555,15765,15243,8441,10067,15406,15234,15608,14758,14835,15882,14787,14727,5351,15859,15721,5663,2543,5013,10394,17548,14647,13548,5345,15760,15685,14731,14906,15330,4577,4744,10984,14759,15639,15090,4221,15422,15441,15736,4683,14768,5375,14843,2554,14995,15638,15837,10002,14584,14730,3458,5911,2760,15812,5367,10174,1645,4090,5576,14975,2877,10206,4778,5322,10207,10740,8450,10517,2758,14729,10743,13527,8444,15738,2445,5931,14728,15615,14646,13526,15343,10105,14645,2433,10268,10245,4706,14918,15694,15421,14208,1396,1444,4051,10061,4701,13257,2949,14946,5656,5608,15352,15817,4119,10223,2969,14648,15658,13256,8425,14524,10075,4137,14847,15886,14877,8036,14579],"beak depth (mm)":{"__ndarray__":"...","dtype":"float64","shape":[156]},"beak length (mm)":{"__ndarray__":"...","dtype":"float64","shape":[156]},"index":[1275,1276,1277,1278,1279,1280,1281,1282,1283,1284,1285,1286,1287,1288,1289,1290,1291,1292,1293,1294,1295,1296,1297,1298,1299,1300,1301,1302,1303,1304,1305,1306,1307,1308,1309,1310,1311,1312,1313,1314,1315,1316,1317,1318,1319,1320,1321,1322,1323,1324,1325,1326,1327,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359,1360,1361,1362,1363,1364,1365,1366,1367,1368,1369,1370,1371,1372,1373,1374,1375,1376,1377,1378,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1402,1403,1404,1405,1406,1407,1408,1409,1410,1411,1412,1413,1414,1415,1416,1417,1418,1419,1420,1421,1422,1423,1424,1425,1426,1427,1428,1429,1430],"species":["scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens","scandens"," ...

# %% [markdown]
# ## Displaying images in Bokeh
#
# Bokeh can also be used to display images, which is useful to zoom in to regions of interest. There are a couple of inconveniences, though, for displaying images with Bokeh. First, Bokeh pushes a lot of data to the browser, and the Jupyter notebook puts a limit on the rate at which it is allowed to do that. In enable Bokeh to display images, with all the pretty zoom capabilities that it provides, you need to increase the data rate to the browser. To do this, you should launch Jupyter from the command line with a flag for higher data rate.
#
#     jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000
#
# Another annoyance is that you explicitly need to specify the plot dimensions by using the `plot_height`, `plot_width`, `x_range`, and `y_range` kwargs of `bokeh.plotting.figure()`. To do this, I wrote a convenient function.

# %%
def bokeh_imshow(im, color_mapper=None):
    """
    Display an image in a Bokeh figure.
    """
    # Get shape
    n, m = im.shape

    # Set up figure with appropriate dimensions
    plot_height = 400
    plot_width = int(m/n * plot_height)
    p = bokeh.plotting.figure(plot_height=plot_height, plot_width=plot_width, 
                              x_range=[0, m], y_range=[0, n],
                              tools='pan,box_zoom,wheel_zoom,reset,resize')

    # Set color mapper; we'll do Viridis with 256 levels by default
    if color_mapper is None:
        color_mapper = bokeh.models.LinearColorMapper(bokeh.palettes.viridis(256))

    # Display the image
    im_bokeh = p.image(image=[im], x=0, y=0, dw=m, dh=n, color_mapper=color_mapper)
    
    return p

# %% [markdown]
# Let's use this function to look at an image of bacteria using Bokeh.

# %%
im = skimage.io.imread('data/bsub_100x_phase.tif')

p = bokeh_imshow(im)
bokeh.io.show(p)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## Exporting plots
#
# Bokeh offers three main options for exporting plots. As we look at them, we will again create the plot of finch beak data from 1987, this time with only the band number showing up when hovering.

# %%
# Build figure
p = bokeh.plotting.figure(height=400, width=600, x_axis_label='beak length (mm)',
                         y_axis_label='beak depth (mm)')

# Set up hover tool
hover = bokeh.models.HoverTool(tooltips=[('band', '@band')])

# Add the tool to the figure
p.add_tools(hover)

# Paint the glyphs
p.circle('beak length (mm)', 'beak depth (mm)', source=df.loc[inds_f, :], color=colors[0], 
         alpha=0.25)
p.circle('beak length (mm)', 'beak depth (mm)', source=df.loc[inds_s, :], color=colors[1],
         alpha=0.25);

# %% [markdown]
# We are not bothering to show the plot here, since it is above, and we are demonstrating output.
#
# The first, and easiest, way to export an image is to click on the 3.5 inch floppy disk icon appearing next to the plot. This will export the plot as a PNG file with reasonable resolution. In my experience, this resolution is sufficient for using the plot in a presentation. You can also export to PNG programmatically.

# %%
bokeh.io.export_png(p, filename='beaks_1987.png')
# Out:
# 'C:\\Users\\Amjad\\git\\bootcamp\\beaks_1987.png'

# %% [markdown]
# I got the above warning, but the PNG rendered just fine.
#
# The second, and most common and useful in my opinion, way is to export the plot as an HTML file. This HTML file can be opened in any browser and will have full interactivity. You could, for example, email the HTML file to your boss, or submit it with a paper. For the time being, this will mostly be in the supplemental materials of a paper, but the paper of the future is interactive, and plots like these will be regularly incorporated into papers.

# %%
# First specify the output file
bokeh.io.output_file('beaks_1987.html', title='Daphne Major finch beaks 1987')

# Save it to HTML
bokeh.io.save(p)
# Out:
# 'C:\\Users\\Amjad\\git\\bootcamp\\beaks_1987.html'

# %% [markdown]
# The function `bokeh.io.save()` returns the full path of the saved file, so you conveniently know where it is.
#
# Finally, if you want to include a plot in a paper of the past (which is often also how the paper of the present is formatted), you want to export vector graphics. As of about a week before the bootcamp, Bokeh has the capability of exporting scalable vector graphics (SVG). These files can be opened and edited in your favorite vector graphics editing software, like Inkscape or Adobe Illustrator. They can also be opened with any modern web browser. You can also convert them to PDF using utilities like [CairoSVG](http://cairosvg.org). So, let's make a nice vector graphics plot!

# %%
# Specify that p's output is SVG
p.output_backend = 'svg'

# Export to SVG
bokeh.io.export_svgs(p, 'beaks_1987.svg')

# Convert the SVG to PDF
#cairosvg.svg2pdf(url='beaks_1987.svg', write_to='beaks_1987.pdf')

# Switch p's output back to HTML canvas, which is more performant for interactivity
p.output_backend = 'canvas'

# %% [markdown]
# There is a lot more you can do with Bokeh.  You can explore more [here](http://bokeh.pydata.org/). Importantly, you can do calculation behind the scenes for your plots, which expands your capabilities to do both analysis and visualization concurrently. Bokeh is rather new and very actively being developed, so I think it holds great promise for the future. It is already my go-to plotting application.
